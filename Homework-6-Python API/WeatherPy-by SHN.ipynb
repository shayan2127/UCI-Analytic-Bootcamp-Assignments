# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 603

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

counter = 1
set_number = 1

url = "http://api.openweathermap.org/data/2.5/weather?units=imperial"

print("Beginning Data Retrieval")
print("-----------------------------")
        
# Build query URL
for city in cities:
    query_url = url + "&appid=" + api_key + "&q=" + city
    #print(query_url)
    try:
        weather = requests.get(query_url)
        weather_json = weather.json()
        #print(weather_json)
    
        city_name.append(weather_json['name'])
        cloudiness.append(weather_json['clouds']['all'])
        country.append(weather_json['sys']['country'])
        date.append(weather_json['dt'])
        humidity.append(weather_json['main']['humidity'])
        lat.append(weather_json['coord']['lat'])
        lng.append(weather_json['coord']['lon'])
        max_temp.append(weather_json['main']['temp_max'])
        wind_speed.append(weather_json['wind']['speed'])
    
    except(KeyError):
        print("City not found. Skipping...")
    
    if counter <= 50:
        print(f"Processing Record {counter} of set {set_number} | {city}")
            
    else:
        counter = 1
        set_number += 1
        print(f"Processing Record {counter} of set {set_number} | {city}")
            
    counter += 1
    
print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of set 1 | cabo san lucas
# Processing Record 2 of set 1 | rikitea
# Processing Record 3 of set 1 | ayacucho
# Processing Record 4 of set 1 | aktau
# City not found. Skipping...
# Processing Record 5 of set 1 | attawapiskat
# Processing Record 6 of set 1 | faanui
# City not found. Skipping...
# Processing Record 7 of set 1 | taolanaro
# Processing Record 8 of set 1 | pevek
# Processing Record 9 of set 1 | hobart
# City not found. Skipping...
# Processing Record 10 of set 1 | illoqqortoormiut
# Processing Record 11 of set 1 | muros
# City not found. Skipping...
# Processing Record 12 of set 1 | belushya guba
# Processing Record 13 of set 1 | abbeville
# Processing Record 14 of set 1 | busselton
# Processing Record 15 of set 1 | kruisfontein
# Processing Record 16 of set 1 | yellowknife
# Processing Record 17 of set 1 | lavrentiya
# Processing Record 18 of set 1 | bluff
# Processing Record 19 of set 1 | punta arenas
# Processing Record 20 of set 1 | jamestown
# Processing Record 21 of set 1 | mocuba
# Processing Record 22 of set 1 | paamiut
# Processing Record 23 of set 1 | burnie
# Processing Record 24 of set 1 | mahebourg
# Processing Record 25 of set 1 | albany
# Processing Record 26 of set 1 | hermanus
# Processing Record 27 of set 1 | buta
# Processing Record 28 of set 1 | avera
# Processing Record 29 of set 1 | vanimo
# Processing Record 30 of set 1 | bialogard
# Processing Record 31 of set 1 | cidreira
# City not found. Skipping...
# Processing Record 32 of set 1 | mocambique
# Processing Record 33 of set 1 | ushuaia
# City not found. Skipping...
# Processing Record 34 of set 1 | olafsvik
# Processing Record 35 of set 1 | padang
# Processing Record 36 of set 1 | mataura
# Processing Record 37 of set 1 | kahului
# Processing Record 38 of set 1 | ibra
# Processing Record 39 of set 1 | namibe
# Processing Record 40 of set 1 | gisborne
# Processing Record 41 of set 1 | honningsvag
# Processing Record 42 of set 1 | ponta do sol
# Processing Record 43 of set 1 | atuona
# Processing Record 44 of set 1 | touros
# Processing Record 45 of set 1 | thompson
# Processing Record 46 of set 1 | guerrero negro
# City not found. Skipping...
# Processing Record 47 of set 1 | aybak
# Processing Record 48 of set 1 | puerto ayora
# City not found. Skipping...
# Processing Record 49 of set 1 | afmadu
# Processing Record 50 of set 1 | kolda
# City not found. Skipping...
# Processing Record 1 of set 2 | tsihombe
# Processing Record 2 of set 2 | camacupa
# Processing Record 3 of set 2 | lebu
# City not found. Skipping...
# Processing Record 4 of set 2 | vaitupu
# Processing Record 5 of set 2 | bethel
# Processing Record 6 of set 2 | camacha
# Processing Record 7 of set 2 | cape town
# Processing Record 8 of set 2 | ulaangom
# City not found. Skipping...
# Processing Record 9 of set 2 | sentyabrskiy
# Processing Record 10 of set 2 | ryotsu
# Processing Record 11 of set 2 | latung
# Processing Record 12 of set 2 | soyo
# Processing Record 13 of set 2 | bandarbeyla
# Processing Record 14 of set 2 | kodiak
# Processing Record 15 of set 2 | vaini
# Processing Record 16 of set 2 | port hedland
# Processing Record 17 of set 2 | aksarka
# Processing Record 18 of set 2 | fairbanks
# Processing Record 19 of set 2 | mitsamiouli
# Processing Record 20 of set 2 | ahipara
# Processing Record 21 of set 2 | acajutla
# Processing Record 22 of set 2 | kokopo
# Processing Record 23 of set 2 | isangel
# Processing Record 24 of set 2 | lata
# Processing Record 25 of set 2 | khilok
# Processing Record 26 of set 2 | butaritari
# Processing Record 27 of set 2 | kurilsk
# Processing Record 28 of set 2 | sindor
# Processing Record 29 of set 2 | marawi
# Processing Record 30 of set 2 | cuamba
# Processing Record 31 of set 2 | puerto del rosario
# Processing Record 32 of set 2 | sao filipe
# Processing Record 33 of set 2 | hilo
# Processing Record 34 of set 2 | saint-paul
# Processing Record 35 of set 2 | nizwa
# Processing Record 36 of set 2 | jalingo
# City not found. Skipping...
# Processing Record 37 of set 2 | artyk
# Processing Record 38 of set 2 | bredasdorp
# Processing Record 39 of set 2 | east london
# Processing Record 40 of set 2 | portland
# Processing Record 41 of set 2 | port alfred
# Processing Record 42 of set 2 | mareeba
# City not found. Skipping...
# Processing Record 43 of set 2 | kopyevo
# Processing Record 44 of set 2 | chokurdakh
# City not found. Skipping...
# Processing Record 45 of set 2 | daxian
# Processing Record 46 of set 2 | emerald
# Processing Record 47 of set 2 | sfantu gheorghe
# Processing Record 48 of set 2 | bilibino
# Processing Record 49 of set 2 | biak
# Processing Record 50 of set 2 | askiz
# Processing Record 1 of set 3 | xuddur
# Processing Record 2 of set 3 | mar del plata
# Processing Record 3 of set 3 | iqaluit
# Processing Record 4 of set 3 | bowen
# City not found. Skipping...
# Processing Record 5 of set 3 | jujuy
# Processing Record 6 of set 3 | torbay
# Processing Record 7 of set 3 | almaznyy
# City not found. Skipping...
# Processing Record 8 of set 3 | kota bahru
# City not found. Skipping...
# Processing Record 9 of set 3 | amderma
# Processing Record 10 of set 3 | anadyr
# Processing Record 11 of set 3 | chuy
# Processing Record 12 of set 3 | rocha
# Processing Record 13 of set 3 | hirara
# Processing Record 14 of set 3 | boa vista
# Processing Record 15 of set 3 | mountain home
# Processing Record 16 of set 3 | porto novo
# Processing Record 17 of set 3 | riyadh
# Processing Record 18 of set 3 | quang ngai
# Processing Record 19 of set 3 | bagacay
# Processing Record 20 of set 3 | nanortalik
# Processing Record 21 of set 3 | kapaa
# Processing Record 22 of set 3 | zelenets
# Processing Record 23 of set 3 | faya
# Processing Record 24 of set 3 | katsuura
# Processing Record 25 of set 3 | cherskiy
# Processing Record 26 of set 3 | lagoa
# Processing Record 27 of set 3 | clyde river
# Processing Record 28 of set 3 | kupang
# Processing Record 29 of set 3 | vila
# Processing Record 30 of set 3 | kharp
# Processing Record 31 of set 3 | tandil
# Processing Record 32 of set 3 | hithadhoo
# Processing Record 33 of set 3 | pochutla
# Processing Record 34 of set 3 | saint-philippe
# Processing Record 35 of set 3 | la rioja
# City not found. Skipping...
# Processing Record 36 of set 3 | tukrah
# Processing Record 37 of set 3 | baykit
# Processing Record 38 of set 3 | jieshi
# Processing Record 39 of set 3 | kavaratti
# Processing Record 40 of set 3 | magadan
# Processing Record 41 of set 3 | dunedin
# Processing Record 42 of set 3 | yar-sale
# Processing Record 43 of set 3 | hasaki
# Processing Record 44 of set 3 | sobolevo
# Processing Record 45 of set 3 | chirnogi
# Processing Record 46 of set 3 | meulaboh
# Processing Record 47 of set 3 | qaanaaq
# Processing Record 48 of set 3 | birr
# Processing Record 49 of set 3 | rio gallegos
# Processing Record 50 of set 3 | biu
# Processing Record 1 of set 4 | ilulissat
# Processing Record 2 of set 4 | luderitz
# Processing Record 3 of set 4 | nchelenge
# Processing Record 4 of set 4 | adunati
# Processing Record 5 of set 4 | luebo
# City not found. Skipping...
# Processing Record 6 of set 4 | bengkulu
# Processing Record 7 of set 4 | wladyslawowo
# Processing Record 8 of set 4 | upernavik
# Processing Record 9 of set 4 | nome
# Processing Record 10 of set 4 | port elizabeth
# Processing Record 11 of set 4 | tubmanburg
# Processing Record 12 of set 4 | prainha
# Processing Record 13 of set 4 | wanning
# City not found. Skipping...
# Processing Record 14 of set 4 | warqla
# Processing Record 15 of set 4 | goderich
# Processing Record 16 of set 4 | lompoc
# Processing Record 17 of set 4 | talnakh
# Processing Record 18 of set 4 | aklavik
# Processing Record 19 of set 4 | yulara
# Processing Record 20 of set 4 | mackenzie
# Processing Record 21 of set 4 | mubi
# City not found. Skipping...
# Processing Record 22 of set 4 | kamenskoye
# Processing Record 23 of set 4 | dikson
# Processing Record 24 of set 4 | caravelas
# Processing Record 25 of set 4 | castro
# Processing Record 26 of set 4 | tuktoyaktuk
# Processing Record 27 of set 4 | sisimiut
# Processing Record 28 of set 4 | znamenskoye
# Processing Record 29 of set 4 | georgetown
# Processing Record 30 of set 4 | ruwi
# Processing Record 31 of set 4 | tarko-sale
# Processing Record 32 of set 4 | new norfolk
# City not found. Skipping...
# Processing Record 33 of set 4 | mahaicony
# Processing Record 34 of set 4 | kendari
# Processing Record 35 of set 4 | nikolskoye
# Processing Record 36 of set 4 | bundaberg
# Processing Record 37 of set 4 | airai
# Processing Record 38 of set 4 | teguise
# Processing Record 39 of set 4 | samarai
# Processing Record 40 of set 4 | kronach
# Processing Record 41 of set 4 | timmins
# Processing Record 42 of set 4 | moerai
# Processing Record 43 of set 4 | tiksi
# Processing Record 44 of set 4 | broome
# Processing Record 45 of set 4 | mopipi
# Processing Record 46 of set 4 | tynda
# Processing Record 47 of set 4 | kyabe
# City not found. Skipping...
# Processing Record 48 of set 4 | juchitan
# Processing Record 49 of set 4 | salima
# Processing Record 50 of set 4 | myaundzha
# Processing Record 1 of set 5 | poddorye
# Processing Record 2 of set 5 | kazachinskoye
# Processing Record 3 of set 5 | auch
# City not found. Skipping...
# Processing Record 4 of set 5 | barentsburg
# Processing Record 5 of set 5 | blenheim
# Processing Record 6 of set 5 | kysyl-syr
# Processing Record 7 of set 5 | yumen
# Processing Record 8 of set 5 | kohlu
# Processing Record 9 of set 5 | praia da vitoria
# Processing Record 10 of set 5 | kaitangata
# Processing Record 11 of set 5 | deputatskiy
# Processing Record 12 of set 5 | ilhabela
# Processing Record 13 of set 5 | lorengau
# City not found. Skipping...
# Processing Record 14 of set 5 | nizhneyansk
# Processing Record 15 of set 5 | gizo
# Processing Record 16 of set 5 | padilla
# Processing Record 17 of set 5 | ust-tsilma
# Processing Record 18 of set 5 | guarapari
# Processing Record 19 of set 5 | carnarvon
# Processing Record 20 of set 5 | college
# Processing Record 21 of set 5 | gigmoto
# Processing Record 22 of set 5 | sao joao da barra
# Processing Record 23 of set 5 | wote
# Processing Record 24 of set 5 | kargasok
# Processing Record 25 of set 5 | varberg
# Processing Record 26 of set 5 | ribeira grande
# Processing Record 27 of set 5 | te anau
# Processing Record 28 of set 5 | fare
# Processing Record 29 of set 5 | geraldton
# Processing Record 30 of set 5 | pitiquito
# Processing Record 31 of set 5 | usinsk
# City not found. Skipping...
# Processing Record 32 of set 5 | nguiu
# Processing Record 33 of set 5 | nerchinskiy zavod
# City not found. Skipping...
# Processing Record 34 of set 5 | lolua
# City not found. Skipping...
# Processing Record 35 of set 5 | bur gabo
# Processing Record 36 of set 5 | gupitan
# Processing Record 37 of set 5 | quelimane
# Processing Record 38 of set 5 | kalmunai
# Processing Record 39 of set 5 | victoria
# Processing Record 40 of set 5 | saldanha
# Processing Record 41 of set 5 | grand gaube
# Processing Record 42 of set 5 | xining
# Processing Record 43 of set 5 | auki
# Processing Record 44 of set 5 | san patricio
# Processing Record 45 of set 5 | praia
# Processing Record 46 of set 5 | raudeberg
# Processing Record 47 of set 5 | souillac
# Processing Record 48 of set 5 | tay ninh
# Processing Record 49 of set 5 | rawson
# Processing Record 50 of set 5 | jiazi
# Processing Record 1 of set 6 | nemuro
# Processing Record 2 of set 6 | khatanga
# Processing Record 3 of set 6 | norman wells
# City not found. Skipping...
# Processing Record 4 of set 6 | rawannawi
# Processing Record 5 of set 6 | narsaq
# Processing Record 6 of set 6 | barcelos
# Processing Record 7 of set 6 | slavonice
# Processing Record 8 of set 6 | sawakin
# Processing Record 9 of set 6 | avarua
# Processing Record 10 of set 6 | mangaratiba
# Processing Record 11 of set 6 | oxford
# Processing Record 12 of set 6 | palmer
# Processing Record 13 of set 6 | enumclaw
# Processing Record 14 of set 6 | cervo
# Processing Record 15 of set 6 | kommunisticheskiy
# Processing Record 16 of set 6 | manjacaze
# Processing Record 17 of set 6 | havoysund
# Processing Record 18 of set 6 | adilabad
# City not found. Skipping...
# Processing Record 19 of set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 20 of set 6 | hihifo
# Processing Record 21 of set 6 | keti bandar
# Processing Record 22 of set 6 | la palma
# Processing Record 23 of set 6 | sabang
# Processing Record 24 of set 6 | nenjiang
# Processing Record 25 of set 6 | dandong
# Processing Record 26 of set 6 | polovinnoye
# Processing Record 27 of set 6 | pasighat
# Processing Record 28 of set 6 | nishihara
# Processing Record 29 of set 6 | axim
# Processing Record 30 of set 6 | bubaque
# Processing Record 31 of set 6 | oshnaviyeh
# Processing Record 32 of set 6 | bay roberts
# Processing Record 33 of set 6 | barrow
# Processing Record 34 of set 6 | clearwater
# Processing Record 35 of set 6 | severo-kurilsk
# Processing Record 36 of set 6 | triunfo
# Processing Record 37 of set 6 | winneba
# Processing Record 38 of set 6 | tuatapere
# City not found. Skipping...
# Processing Record 39 of set 6 | bargal
# City not found. Skipping...
# Processing Record 40 of set 6 | solsvik
# City not found. Skipping...
# Processing Record 41 of set 6 | imabari
# Processing Record 42 of set 6 | petalcingo
# Processing Record 43 of set 6 | pathein
# Processing Record 44 of set 6 | severo-yeniseyskiy
# Processing Record 45 of set 6 | sabha
# Processing Record 46 of set 6 | sumisip
# Processing Record 47 of set 6 | masuguru
# Processing Record 48 of set 6 | sitka
# Processing Record 49 of set 6 | hailey
# Processing Record 50 of set 6 | beringovskiy
# Processing Record 1 of set 7 | pacific grove
# City not found. Skipping...
# Processing Record 2 of set 7 | ji-parana
# Processing Record 3 of set 7 | tabou
# Processing Record 4 of set 7 | henties bay
# Processing Record 5 of set 7 | provideniya
# Processing Record 6 of set 7 | chowchilla
# Processing Record 7 of set 7 | presidencia roque saenz pena
# Processing Record 8 of set 7 | prudentopolis
# Processing Record 9 of set 7 | klyuchi
# Processing Record 10 of set 7 | tiznit
# City not found. Skipping...
# Processing Record 11 of set 7 | yetholm
# City not found. Skipping...
# Processing Record 12 of set 7 | asau
# Processing Record 13 of set 7 | fomboni
# Processing Record 14 of set 7 | tiarei
# Processing Record 15 of set 7 | amberley
# Processing Record 16 of set 7 | garissa
# Processing Record 17 of set 7 | rincon
# Processing Record 18 of set 7 | strelka
# City not found. Skipping...
# Processing Record 19 of set 7 | umm durman
# Processing Record 20 of set 7 | ixtapa
# Processing Record 21 of set 7 | taoudenni
# Processing Record 22 of set 7 | nouadhibou
# Processing Record 23 of set 7 | roald
# Processing Record 24 of set 7 | gamba
# Processing Record 25 of set 7 | umm lajj
# City not found. Skipping...
# Processing Record 26 of set 7 | palabuhanratu
# Processing Record 27 of set 7 | buala
# Processing Record 28 of set 7 | sanming
# Processing Record 29 of set 7 | kondinskoye
# Processing Record 30 of set 7 | half moon bay
# Processing Record 31 of set 7 | omsukchan
# Processing Record 32 of set 7 | sucre
# City not found. Skipping...
# Processing Record 33 of set 7 | bolungarvik
# Processing Record 34 of set 7 | ancud
# Processing Record 35 of set 7 | hami
# Processing Record 36 of set 7 | oranjemund
# Processing Record 37 of set 7 | uporovo
# Processing Record 38 of set 7 | kafanchan
# Processing Record 39 of set 7 | komsomolskiy
# Processing Record 40 of set 7 | yerbogachen
# Processing Record 41 of set 7 | rajbiraj
# Processing Record 42 of set 7 | erenhot
# Processing Record 43 of set 7 | aasiaat
# Processing Record 44 of set 7 | polunochnoye
# Processing Record 45 of set 7 | eldorado
# Processing Record 46 of set 7 | atar
# City not found. Skipping...
# Processing Record 47 of set 7 | tabiauea
# Processing Record 48 of set 7 | hengyang
# Processing Record 49 of set 7 | maxixe
# Processing Record 50 of set 7 | ouallam
# Processing Record 1 of set 8 | richards bay
# Processing Record 2 of set 8 | tecoanapa
# Processing Record 3 of set 8 | araouane
# Processing Record 4 of set 8 | harper
# Processing Record 5 of set 8 | arraial do cabo
# Processing Record 6 of set 8 | lixourion
# Processing Record 7 of set 8 | port lincoln
# Processing Record 8 of set 8 | stege
# Processing Record 9 of set 8 | kieta
# Processing Record 10 of set 8 | iracoubo
# City not found. Skipping...
# Processing Record 11 of set 8 | dolbeau
# Processing Record 12 of set 8 | batemans bay
# Processing Record 13 of set 8 | kamenka
# Processing Record 14 of set 8 | thinadhoo
# Processing Record 15 of set 8 | parian dakula
# Processing Record 16 of set 8 | orange walk
# Processing Record 17 of set 8 | petropavlovsk-kamchatskiy
# Processing Record 18 of set 8 | nakhon phanom
# Processing Record 19 of set 8 | mount gambier
# Processing Record 20 of set 8 | ananindeua
# Processing Record 21 of set 8 | hofn
# Processing Record 22 of set 8 | yaan
# Processing Record 23 of set 8 | saskylakh
# Processing Record 24 of set 8 | vao
# Processing Record 25 of set 8 | atambua
# Processing Record 26 of set 8 | shimoda
# Processing Record 27 of set 8 | teluknaga
# Processing Record 28 of set 8 | shobara
# Processing Record 29 of set 8 | pitimbu
# Processing Record 30 of set 8 | dwarka
# Processing Record 31 of set 8 | dunmore town
# Processing Record 32 of set 8 | rio grande
# Processing Record 33 of set 8 | port blair
# Processing Record 34 of set 8 | codrington
# Processing Record 35 of set 8 | broken hill
# Processing Record 36 of set 8 | yukon
# Processing Record 37 of set 8 | ankang
# Processing Record 38 of set 8 | lundazi
# Processing Record 39 of set 8 | tsabong
# Processing Record 40 of set 8 | oussouye
# Processing Record 41 of set 8 | sola
# Processing Record 42 of set 8 | bridgwater
# Processing Record 43 of set 8 | udachnyy
# Processing Record 44 of set 8 | santiago del estero
# Processing Record 45 of set 8 | sechura
# Processing Record 46 of set 8 | itarema
# Processing Record 47 of set 8 | beckley
# Processing Record 48 of set 8 | karatau
# Processing Record 49 of set 8 | petropavl
# Processing Record 50 of set 8 | victor harbor
# Processing Record 1 of set 9 | los llanos de aridane
# Processing Record 2 of set 9 | taupo
# Processing Record 3 of set 9 | tefe
# Processing Record 4 of set 9 | anaconda
# Processing Record 5 of set 9 | grunberg
# Processing Record 6 of set 9 | bulgan
# Processing Record 7 of set 9 | ca mau
# Processing Record 8 of set 9 | cubuk
# Processing Record 9 of set 9 | pangoa
# Processing Record 10 of set 9 | rahuri
# Processing Record 11 of set 9 | wasilla
# Processing Record 12 of set 9 | chuguyevka
# Processing Record 13 of set 9 | skjervoy
# Processing Record 14 of set 9 | banfora
# Processing Record 15 of set 9 | hovd
# Processing Record 16 of set 9 | teixoso
# Processing Record 17 of set 9 | nyanguge
# Processing Record 18 of set 9 | baherden
# City not found. Skipping...
# Processing Record 19 of set 9 | port-de-paix
# Processing Record 20 of set 9 | minot
# Processing Record 21 of set 9 | colquechaca
# Processing Record 22 of set 9 | tura
# Processing Record 23 of set 9 | awbari
# Processing Record 24 of set 9 | tasiilaq
# Processing Record 25 of set 9 | comodoro rivadavia
# Processing Record 26 of set 9 | kavieng
# Processing Record 27 of set 9 | mahajanga
# Processing Record 28 of set 9 | port hardy
# Processing Record 29 of set 9 | alice springs
# Processing Record 30 of set 9 | okhotsk
# Processing Record 31 of set 9 | yarada
# Processing Record 32 of set 9 | saint george
# Processing Record 33 of set 9 | caraballeda
# Processing Record 34 of set 9 | zhangye
# City not found. Skipping...
# Processing Record 35 of set 9 | samusu
# Processing Record 36 of set 9 | pisco
# Processing Record 37 of set 9 | maceio
# Processing Record 38 of set 9 | olinda
# Processing Record 39 of set 9 | westport
# Processing Record 40 of set 9 | netishyn
# Processing Record 41 of set 9 | rosarito
# Processing Record 42 of set 9 | tara
# Processing Record 43 of set 9 | farafangana
# Processing Record 44 of set 9 | ozinki
# Processing Record 45 of set 9 | snezhnogorsk
# Processing Record 46 of set 9 | dzhebariki-khaya
# Processing Record 47 of set 9 | esperanca
# Processing Record 48 of set 9 | povenets
# Processing Record 49 of set 9 | berlevag
# Processing Record 50 of set 9 | amod
# Processing Record 1 of set 10 | astoria
# City not found. Skipping...
# Processing Record 2 of set 10 | rudbar
# Processing Record 3 of set 10 | warrnambool
# Processing Record 4 of set 10 | longyearbyen
# Processing Record 5 of set 10 | talin
# Processing Record 6 of set 10 | naze
# Processing Record 7 of set 10 | verkhneye dubrovo
# Processing Record 8 of set 10 | baghdad
# Processing Record 9 of set 10 | lima
# Processing Record 10 of set 10 | villarrobledo
# Processing Record 11 of set 10 | cairns
# Processing Record 12 of set 10 | fortuna
# Processing Record 13 of set 10 | otjimbingwe
# Processing Record 14 of set 10 | callaway
# Processing Record 15 of set 10 | port macquarie
# Processing Record 16 of set 10 | itaituba
# City not found. Skipping...
# Processing Record 17 of set 10 | meyungs
# Processing Record 18 of set 10 | leninskoye
# Processing Record 19 of set 10 | svetlogorsk
# Processing Record 20 of set 10 | jardim
# Processing Record 21 of set 10 | byron bay
# Processing Record 22 of set 10 | lazaro cardenas
# Processing Record 23 of set 10 | cartagena
# Processing Record 24 of set 10 | yeppoon
# Processing Record 25 of set 10 | nara
# Processing Record 26 of set 10 | leningradskiy
# Processing Record 27 of set 10 | bestobe
# City not found. Skipping...
# Processing Record 28 of set 10 | korla
# City not found. Skipping...
# Processing Record 29 of set 10 | pinotepa nacional
# Processing Record 30 of set 10 | marystown
# Processing Record 31 of set 10 | barrhead
# Processing Record 32 of set 10 | high level
# Processing Record 33 of set 10 | igarka
# Processing Record 34 of set 10 | gambo
# Processing Record 35 of set 10 | nakamura
# Processing Record 36 of set 10 | lulea
# City not found. Skipping...
# Processing Record 37 of set 10 | yanan
# Processing Record 38 of set 10 | saint-augustin
# Processing Record 39 of set 10 | hamilton
# Processing Record 40 of set 10 | cayenne
# Processing Record 41 of set 10 | tevriz
# Processing Record 42 of set 10 | ghanzi
# City not found. Skipping...
# Processing Record 43 of set 10 | tuggurt
# Processing Record 44 of set 10 | petrov val
# Processing Record 45 of set 10 | gornopravdinsk
# Processing Record 46 of set 10 | santa rosa
# City not found. Skipping...
# Processing Record 47 of set 10 | jiddah
# Processing Record 48 of set 10 | salalah
# Processing Record 49 of set 10 | charters towers
# Processing Record 50 of set 10 | kutahya
# Processing Record 1 of set 11 | oriximina
# Processing Record 2 of set 11 | charleston
# Processing Record 3 of set 11 | chantada
# Processing Record 4 of set 11 | yanam
# Processing Record 5 of set 11 | morondava
# City not found. Skipping...
# Processing Record 6 of set 11 | formoso do araguaia
# Processing Record 7 of set 11 | chaohu
# Processing Record 8 of set 11 | barsovo
# Processing Record 9 of set 11 | port keats
# Processing Record 10 of set 11 | dingli
# Processing Record 11 of set 11 | vila do maio
# Processing Record 12 of set 11 | ust-ilimsk
# City not found. Skipping...
# Processing Record 13 of set 11 | atka
# Processing Record 14 of set 11 | goundam
# Processing Record 15 of set 11 | lasa
# City not found. Skipping...
# Processing Record 16 of set 11 | ndele
# Processing Record 17 of set 11 | cantanhede
# Processing Record 18 of set 11 | ucluelet
# Processing Record 19 of set 11 | horadiz
# Processing Record 20 of set 11 | tazmalt
# Processing Record 21 of set 11 | albignasego
# Processing Record 22 of set 11 | adrar
# City not found. Skipping...
# Processing Record 23 of set 11 | grand river south east
# Processing Record 24 of set 11 | bambous virieux
# Processing Record 25 of set 11 | san juan de los morros
# Processing Record 26 of set 11 | fernley
# Processing Record 27 of set 11 | yen bai
# Processing Record 28 of set 11 | altamont
# Processing Record 29 of set 11 | sungaipenuh
# Processing Record 30 of set 11 | eyl
# Processing Record 31 of set 11 | tegh
# Processing Record 32 of set 11 | lubao
# Processing Record 33 of set 11 | port augusta
# Processing Record 34 of set 11 | gwanda
# Processing Record 35 of set 11 | yakeshi
# Processing Record 36 of set 11 | elizabeth city
# Processing Record 37 of set 11 | ipixuna
# City not found. Skipping...
# Processing Record 38 of set 11 | krasnoselkup
# Processing Record 39 of set 11 | lewistown
# Processing Record 40 of set 11 | shingu
# Processing Record 41 of set 11 | swan hill
# City not found. Skipping...
# Processing Record 42 of set 11 | tumannyy
# Processing Record 43 of set 11 | pacifica
# City not found. Skipping...
# Processing Record 44 of set 11 | bokspits
# Processing Record 45 of set 11 | aras
# Processing Record 46 of set 11 | rassvet
# City not found. Skipping...
# Processing Record 47 of set 11 | kashi
# Processing Record 48 of set 11 | tongliao
# Processing Record 49 of set 11 | vestmannaeyjar
# Processing Record 50 of set 11 | dve mogili
# Processing Record 1 of set 12 | mujiayingzi
# Processing Record 2 of set 12 | serenje
# Processing Record 3 of set 12 | show low
# City not found. Skipping...
# Processing Record 4 of set 12 | sakakah
# Processing Record 5 of set 12 | arman
# Processing Record 6 of set 12 | chicama
# Processing Record 7 of set 12 | lingao
# City not found. Skipping...
# Processing Record 8 of set 12 | old road
# Processing Record 9 of set 12 | north bend
# Processing Record 10 of set 12 | mayo
# Processing Record 11 of set 12 | natal
# Processing Record 12 of set 12 | chapais
# Processing Record 13 of set 12 | pangnirtung
# Processing Record 14 of set 12 | puerto colombia
# Processing Record 15 of set 12 | kem
# Processing Record 16 of set 12 | capinota
# Processing Record 17 of set 12 | kindu
# Processing Record 18 of set 12 | lugovoy
# Processing Record 19 of set 12 | nileshwar
# Processing Record 20 of set 12 | vila velha
# Processing Record 21 of set 12 | sambava
# Processing Record 22 of set 12 | eston
# Processing Record 23 of set 12 | bonavista
# Processing Record 24 of set 12 | imaculada
# Processing Record 25 of set 12 | palu
# Processing Record 26 of set 12 | vavatenina
# Processing Record 27 of set 12 | vaitape
# City not found. Skipping...
# Processing Record 28 of set 12 | katsiveli
# Processing Record 29 of set 12 | medicine hat
# Processing Record 30 of set 12 | buraydah
# Processing Record 31 of set 12 | la peca
# Processing Record 32 of set 12 | majene
# Processing Record 33 of set 12 | morwell
# Processing Record 34 of set 12 | gat
# City not found. Skipping...
# Processing Record 35 of set 12 | cheuskiny
# Processing Record 36 of set 12 | barentu
# Processing Record 37 of set 12 | riachao das neves
# Processing Record 38 of set 12 | sivas
# Processing Record 39 of set 12 | hobyo
# Processing Record 40 of set 12 | walvis bay
# Processing Record 41 of set 12 | piranhas
# City not found. Skipping...
# Processing Record 42 of set 12 | el faiyum
# Processing Record 43 of set 12 | mataram
# Processing Record 44 of set 12 | brownsville
# Processing Record 45 of set 12 | trincomalee
# Processing Record 46 of set 12 | algiers
# Processing Record 47 of set 12 | mach
# Processing Record 48 of set 12 | cabedelo
# Processing Record 49 of set 12 | heinola
# Processing Record 50 of set 12 | cap malheureux
# Processing Record 1 of set 13 | shikhazany
# Processing Record 2 of set 13 | san pedro
# Processing Record 3 of set 13 | santa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
columns_check = {"City": len(city_name), "Cloudiness": len(cloudiness), "Country": len(country),
                 "Date": len(date), "Humidity": len(humidity), "Lat": len(lat), "Lng": len(lng),
                 "Max Temp": len(max_temp), "Max Windspeed": len(wind_speed)
}

# Convert columns into a series
len_check = pd.Series(columns_check)
print(len_check)
# Out:
# City             539
# Cloudiness       539
# Country          539
# Date             539
# Humidity         539
# Lat              539
# Lng              539
# Max Temp         539
# Max Windspeed    539
# dtype: int64

# %%
weather_frame = pd.DataFrame({"City": city_name, 
                             "Cloudiness": cloudiness, 
                             "Country": country, 
                             "Date": date, 
                             "Humidity": humidity, 
                             "Lat": lat, 
                             "Lng": lng, 
                             "Max Temp": max_temp, 
                             "Max Windspeed": wind_speed
})
                 
weather_frame.head()
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  Cabo San Lucas          40      MX  1536461520        74  22.89 -109.91
# 1         Rikitea          88      PF  1536463413        98 -23.12 -134.97
# 2        Ayacucho          44      PE  1536463676        82 -13.16  -74.23
# 3           Aktau          20      KZ  1536460200        22  43.65   51.16
# 4          Faanui           0      PF  1536463962       100 -16.48 -151.75
#
#    Max Temp  Max Windspeed
# 0     80.60           5.82
# 1     74.06          14.23
# 2     37.52           2.37
# 3     68.00          15.66
# 4     77.57           3.94

# %%
#save the file to what we define at the top:

weather_frame.to_csv(output_data_file, index=False, header=True)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(lat, max_temp, marker="o", facecolors="blue", edgecolors="black", label="Temp", alpha=0.5)

plt.grid()

plt.title("City Latitude va. Maximum Temprature (08/22/18)")
plt.xlabel("Latitude")
plt.ylabel("Max Temprature(F)")

plt.savefig("../Images/Lat_Temp.png")

plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(lat, humidity, marker="o", facecolors="green", edgecolors="black", label="Humidity", alpha=0.5)

plt.grid()

plt.title("City Latitude va. Humidity (08/22/18)")
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")

plt.savefig("../Images/Lat_Humidity.png")

plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(lat, cloudiness, marker="o", facecolors="yellow", edgecolors="black", label="Cloudiness", alpha=0.5)

plt.grid()

plt.title("City Latitude va. Cloudiness (08/22/18)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")

plt.savefig("../Images/Lat_Cloudiness.png")

plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(lat, wind_speed, marker="o", facecolors="magenta", edgecolors="black", label="Windspeed", alpha=0.5)

plt.grid()

plt.title("City Latitude va. Wind Speed (08/22/18)")
plt.xlabel("Latitude")
plt.ylabel("Windspeed(mph)")

plt.savefig("../Images/Lat_Windspeed.png")

plt.show()
